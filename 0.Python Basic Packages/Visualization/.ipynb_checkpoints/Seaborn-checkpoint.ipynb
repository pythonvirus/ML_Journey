# %% [markdown]
# ## Histograms

# %%
import numpy as np
from numpy.random import randn
import pandas as pd

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#Create a random normal-dist dataset
dataset1 = randn(100)

plt.hist(dataset1)
# Out:
# (array([ 3.,  3.,  8., 12., 11., 17., 15., 19.,  7.,  5.]),
#  array([-2.43129444, -2.02219078, -1.61308713, -1.20398347, -0.79487981,
#         -0.38577615,  0.0233275 ,  0.43243116,  0.84153482,  1.25063848,
#          1.65974213]),
#  <a list of 10 Patch objects>)

# %%
# Lets make another dataset
dataset2 = randn(80)

plt.hist(dataset2,color='indianred')
# Out:
# (array([ 1.,  9.,  8., 10., 10., 14., 13.,  6.,  7.,  2.]),
#  array([-2.41583468, -1.92921616, -1.44259764, -0.95597911, -0.46936059,
#          0.01725793,  0.50387645,  0.99049497,  1.47711349,  1.96373202,
#          2.45035054]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,alpha=0.25,bins=20)
# Out:
# /home/abhinandan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/abhinandan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([0.05137495, 0.        , 0.05137495, 0.41099956, 0.15412484,
#         0.25687473, 0.20549978, 0.30824967, 0.30824967, 0.20549978,
#         0.41099956, 0.30824967, 0.35962462, 0.30824967, 0.10274989,
#         0.20549978, 0.15412484, 0.20549978, 0.        , 0.10274989]),
#  array([-2.41583468, -2.17252542, -1.92921616, -1.6859069 , -1.44259764,
#         -1.19928837, -0.95597911, -0.71266985, -0.46936059, -0.22605133,
#          0.01725793,  0.26056719,  0.50387645,  0.74718571,  0.99049497,
#          1.23380423,  1.47711349,  1.72042276,  1.96373202,  2.20704128,
#          2.45035054]),
#  <a list of 20 Patch objects>)

# %%
# Make two more random normal dist data sets
data1 = randn(1000)
data2 = randn(1000)

sns.jointplot(data1,data2)
# Out:
# /home/abhinandan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/abhinandan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(data1,data2,kind='kde')

# %% [markdown]
# ## DistPlot

# %%
# Create datset
dataset = randn(100)

# Use distplot for combining plots, by default a kde over a histogram is shown
sns.distplot(dataset,bins=25)
# Out:
# /home/abhinandan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## Regression Plots

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot("total_bill","tip",tips)

# %%
sns.lmplot("total_bill","tip",tips,ci=75)

# %%
sns.lmplot("total_bill", "tip", tips,
           scatter_kws={"marker": "o", "color": "indianred"},
           line_kws={"linewidth": 1, "color": "blue"});

# %%
# Create a new column for tip percentage
tips["tip_pect"]=100*(tips['tip']/tips['total_bill'])

#plot
sns.lmplot("size", "tip_pect", tips);

# %%
sns.lmplot("size", "tip_pect", tips, x_estimator=np.mean);

# %%
sns.lmplot("total_bill", "tip_pect", tips, hue="sex",markers=["x","o"])

# %%
sns.lmplot("total_bill", "tip_pect", tips, hue="day")

# %% [markdown]
# ### Heatmaps

# %%
flight_dframe = sns.load_dataset('flights')
flight_dframe.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flight_dframe = flight_dframe.pivot("month","year","passengers")
flight_dframe
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# December    118   140   166   194   201   229   278   306   336   337   405
#
# year       1960
# month
# January     417
# February    391
# March       419
# April       461
# May         472
# June        535
# July        622
# August      606
# September   508
# October     461
# November    390
# December    432

# %%
sns.heatmap(flight_dframe)

# %%
sns.heatmap(flight_dframe,annot=True,fmt='d')

# %%
# heatmap() can be used on an axes for a subplot to create more informative figures
f, (axis1,axis2) = plt.subplots(2,1)

years = pd.DataFrame(flight_dframe.sum().index.values)
flights = pd.DataFrame(flight_dframe.sum().values)

# Make the dframe and name columns
year_dframe = pd.concat((years,flights),axis=1)
year_dframe.columns = ['Year','Flights']

# Create the bar plot on top
sns.barplot('Year',y='Flights',data=year_dframe, ax = axis1)

# Create the heatmap on bottom
sns.heatmap(flight_dframe,ax=axis2,cbar_kws={"orientation": "horizontal"})

# %%
# Clustermap will reformat the heatmap so similar rows are next to each other
sns.clustermap(flight_dframe)
